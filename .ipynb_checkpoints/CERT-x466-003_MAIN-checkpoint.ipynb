# %% [markdown]
# # <center><u>**CERT x466-003**</u>: Data Storytelling<br>AI Job Market Data Exploration and Storytelling</center>
#
# <figure style="text-align: center;">
#     <img src="notebook_images/ai_jobMarket01.png" alt="AI Job Market">
# </figure>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## DOWNLOAD AND UNZIP DATASET FROM KAGGLE

# %%
from dotenv import load_dotenv
load_dotenv()

import kaggle
kaggle.api.dataset_download_files('shree0910/ai-and-data-science-job-market-dataset-20202026', path='./data', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/shree0910/ai-and-data-science-job-market-dataset-20202026

# %% [markdown]
# ---

# %% [markdown]
# ## GPU ACCELERATION

# %%
# %load_ext cudf.pandas
# %load_ext cuml.accel
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('load_ext', 'cudf.pandas')
#       2 get_ipython().run_line_magic('load_ext', 'cuml.accel')
#
# File ~/000_Duckspace/WanderduckDevelopment/Ducks/UMN/CERT-x466-003/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2532, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2530     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2531 with self.builtin_trap:
# -> 2532     result = fn(*args, **kwargs)
#    2534 # The code below prevents the output from being displayed
#    2535 # when using magics with decorator @output_can_be_silenced
#    2536 # when the last Python token in the expression is a ';'.
#    2537 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/000_Duckspace/WanderduckDevelopment/Ducks/UMN/CERT-x466-003/.venv/lib/python3.13/site-packages/IPython/core/magics/extension.py:33, in ExtensionMagics.load_ext(self, module_str)
#      31 if not module_str:
#      32     raise UsageError('Missing module name.')
# ---> 33 res = self.shell.extension_manager.load_extension(module_str)
#      35 if res == 'already loaded':
#      36     print("The %s extension is already loaded. To reload it, use:" % module_str)
#
# File ~/000_Duckspace/WanderduckDevelopment/Ducks/UMN/CERT-x466-003/.venv/lib/python3.13/site-packages/IPython/core/extensions.py:62, in ExtensionManager.load_extension(self, module_str)
#      55 """Load an IPython extension by its module name.
#      56
#      57 Returns the string "already loaded" if the extension is already loaded,
#      58 "no load function" if the module doesn't have a load_ipython_extension
#      59 function, or None if it succeeded.
#      60 """
#      61 try:
# ---> 62     return self._load_extension(module_str)
#      63 except ModuleNotFoundError:
#      64     if module_str in BUILTINS_EXTS:
#
# File ~/000_Duckspace/WanderduckDevelopment/Ducks/UMN/CERT-x466-003/.venv/lib/python3.13/site-packages/IPython/core/extensions.py:77, in ExtensionManager._load_extension(self, module_str)
#      75 with self.shell.builtin_trap:
#      76     if module_str not in sys.modules:
# ---> 77         mod = import_module(module_str)
#      78     mod = sys.modules[module_str]
#      79     if self._call_load_ipython_extension(mod):
#
# File ~/.local/share/uv/python/cpython-3.13.6-linux-x86_64-gnu/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1310, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1026, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/000_Duckspace/WanderduckDevelopment/Ducks/UMN/CERT-x466-003/.venv/lib/python3.13/site-packages/cudf/__init__.py:20
#      17 from rmm.allocators.cupy import rmm_cupy_allocator
#      18 from rmm.allocators.numba import RMMNumbaManager
# ---> 20 from cudf import api, core, datasets, testing
#      21 from cudf._version import __git_commit__, __version__
#      22 from cudf.api.extensions import (
#      23     register_dataframe_accessor,
#      24     register_index_accessor,
#      25     register_series_accessor,
#      26 )
#
# File ~/000_Duckspace/WanderduckDevelopment/Ducks/UMN/CERT-x466-003/.venv/lib/python3.13/site-packages/cudf/api/__init__.py:4
#       1 # SPDX-FileCopyrightText: Copyright (c) 2021, NVIDIA CORPORATION.
#       2 # SPDX-License-Identifier: Apache-2.0
# ----> 4 from cudf.api import extensions, types
#       6 __all__ = ["extensions", "types"]
#
# File ~/000_Duckspace/WanderduckDevelopment/Ducks/UMN/CERT-x466-003/.venv/lib/python3.13/site-packages/cudf/api/extensions/__init__.py:6
#       1 # SPDX-FileCopyrightText: Copyright (c) 2020-2023, NVIDIA CORPORATION.
#       2 # SPDX-License-Identifier: Apache-2.0
#       4 from pandas.api.extensions import no_default
# ----> 6 from cudf.api.extensions.accessor import (
#       7     register_dataframe_accessor,
#       8     register_index_accessor,
#       9     register_series_accessor,
#      10 )
#      12 __all__ = [
#      13     "no_default",
#      14     "register_dataframe_accessor",
#      15     "register_index_accessor",
#      16     "register_series_accessor",
#      17 ]
#
# File ~/000_Duckspace/WanderduckDevelopment/Ducks/UMN/CERT-x466-003/.venv/lib/python3.13/site-packages/cudf/api/extensions/accessor.py:8
#       4 import warnings
#       6 from pandas.core.accessor import CachedAccessor
# ----> 8 from cudf.core.dataframe import DataFrame
#       9 from cudf.core.index import Index
#      10 from cudf.core.series import Series
#
# File ~/000_Duckspace/WanderduckDevelopment/Ducks/UMN/CERT-x466-003/.venv/lib/python3.13/site-packages/cudf/core/dataframe.py:43
#      41 import cudf
#      42 from cudf.api.extensions import no_default
# ---> 43 from cudf.api.types import (
#      44     _is_categorical_dtype,
#      45     _is_scalar_or_zero_d_array,
#      46     is_decimal32_dtype,
#      47     is_decimal64_dtype,
#      48     is_decimal128_dtype,
#      49     is_dict_like,
#      50     is_dtype_equal,
#      51     is_list_like,
#      52     is_scalar,
#      53 )
#      54 from cudf.core import indexing_utils, reshape
#      55 from cudf.core._compat import PANDAS_LT_300
#
# File ~/000_Duckspace/WanderduckDevelopment/Ducks/UMN/CERT-x466-003/.venv/lib/python3.13/site-packages/cudf/api/types.py:525
#     523 is_float = pd_types.is_float
#     524 is_hashable = pd_types.is_hashable
# --> 525 is_interval = pd_types.is_interval
#     526 is_number = pd_types.is_number
#     527 is_re = pd_types.is_re
#
# AttributeError: module 'pandas.api.types' has no attribute 'is_interval'

# %% [markdown]
# ---

# %% [markdown]
# ## IMPORTS

# %% [markdown]
# ---

# %% [markdown]
# ## DATASET LOADING

# %% [markdown]
# ---
